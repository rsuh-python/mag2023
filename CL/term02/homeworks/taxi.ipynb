# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data = pd.read_csv('/content/gdrive/My Drive/data_stud/machlearn/out.csv')
data.head ()
#датасет обрезан до 30к строк, потому что я не могу обработать 5 гб...
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count
# 0                1
# 1                1
# 2                2
# ...

# %%
data['pickup_datetime'] = pd.to_datetime(data['pickup_datetime'])
data.head ()
# Out:
#                              key  fare_amount           pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5 2009-06-15 17:26:21+00:00
# 1    2010-01-05 16:52:16.0000002         16.9 2010-01-05 16:52:16+00:00
# 2   2011-08-18 00:35:00.00000049          5.7 2011-08-18 00:35:00+00:00
# 3    2012-04-21 04:30:42.0000001          7.7 2012-04-21 04:30:42+00:00
# 4  2010-03-09 07:51:00.000000135          5.3 2010-03-09 07:51:00+00:00
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count
# 0                1
# 1                1
# 2                2
# ...

# %%
data["year"] = data['pickup_datetime'].dt.year
data["month"] = data['pickup_datetime'].dt.month
data["day"] = data['pickup_datetime'].dt.day
data["hour"] = data['pickup_datetime'].dt.hour
data["minute"] = data['pickup_datetime'].dt.minute
data["dayofweek"] = data['pickup_datetime'].dt.dayofweek
data = data.drop(['key'], axis=1)

data.head ()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          4.5 2009-06-15 17:26:21+00:00        -73.844311        40.721319
# 1         16.9 2010-01-05 16:52:16+00:00        -74.016048        40.711303
# 2          5.7 2011-08-18 00:35:00+00:00        -73.982738        40.761270
# 3          7.7 2012-04-21 04:30:42+00:00        -73.987130        40.733143
# 4          5.3 2010-03-09 07:51:00+00:00        -73.968095        40.768008
#
#    dropoff_longitude  dropoff_latitude  passenger_count  year  month  day  \
# 0         -73.841610         40.712278                1  2009      6   15
# 1         -73.979268         40.782004                1  2010      1    5
# 2         -73.991242         40.750562                2  2011      8   18
# 3         -73.991567         40.758092                1  2012      4   21
# 4         -73.956655         40.783762                1  2010      3    9
#
#    hour  minute  dayofweek
# 0    17      26          0
# ...

# %%
data = data.drop(['pickup_datetime'], axis=1)

# %%
data = data.dropna ()
data.isna().any()
# Out:
# fare_amount          False
# pickup_longitude     False
# pickup_latitude      False
# dropoff_longitude    False
# dropoff_latitude     False
# passenger_count      False
# year                 False
# month                False
# day                  False
# hour                 False
# minute               False
# dayofweek            False
# dtype: bool

# %%
"""from sklearn import preprocessing
x = data.values
robust = preprocessing.RobustScaler()
x_scaled = robust.fit_transform(x)
data1=pd.DataFrame(x_scaled, columns=data.columns)

data1.head()"""
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0    -0.615385          5.480549        -0.971328           5.042244
# 1     1.292308         -1.368248        -1.280121           0.033728
# 2    -0.430769         -0.039860         0.260359          -0.401931
# 3    -0.123077         -0.215011        -0.606795          -0.413756
# 4    -0.492308          0.544097         0.468091           0.856474
#
#    dropoff_latitude  passenger_count      year     month       day  hour  \
# 0         -1.224728              0.0 -1.000000  0.000000 -0.066667   0.3
# 1          0.843173              0.0 -0.666667 -0.833333 -0.733333   0.2
# 2         -0.089319              1.0 -0.333333  0.333333  0.133333  -1.4
# 3          0.134002              0.0  0.000000 -0.333333  0.333333  -1.0
# 4          0.895311              0.0 -0.666667 -0.500000 -0.466667  -0.7
#
#      minute  dayofweek
# 0 -0.133333      -0.75
# 1  0.733333      -0.50
# 2  0.166667       0.00
# ...

# %%
from sklearn import preprocessing
x = data.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
data1=pd.DataFrame(x_scaled, columns=data.columns)

data1.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0     0.036946          0.013515         0.241487           0.086186
# 1     0.098030          0.012037         0.241466           0.085089
# 2     0.042857          0.012324         0.241571           0.084993
# 3     0.052709          0.012286         0.241512           0.084991
# 4     0.040887          0.012450         0.241585           0.085269
#
#    dropoff_latitude  passenger_count      year     month       day      hour  \
# 0          0.976981         0.166667  0.000000  0.454545  0.466667  0.739130
# 1          0.977575         0.166667  0.166667  0.000000  0.133333  0.695652
# 2          0.977307         0.333333  0.333333  0.636364  0.566667  0.000000
# 3          0.977371         0.166667  0.500000  0.272727  0.666667  0.173913
# 4          0.977590         0.166667  0.166667  0.181818  0.266667  0.304348
#
#      minute  dayofweek
# 0  0.440678   0.000000
# 1  0.881356   0.166667
# ...

# %%
from sklearn.model_selection import train_test_split

X = data1.drop('fare_amount', axis=1)
y = data1['fare_amount'].astype('float')

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.2)

X.shape
# Out:
# (30000, 11)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()

model.fit(Xtrain, ytrain)
# Out:
# LinearRegression()

# %%
pred_train = model.predict(Xtrain)
pred_test = model.predict(Xtest)
print(mean_squared_error(pred_test, ytest) ** 0.5, mean_squared_error(pred_train, ytrain) ** 0.5)
# Out:
# 0.04799025907220509 0.04695169913516091

# %%
testing = pd.read_csv('/content/gdrive/My Drive/data_stud/machlearn/test.csv')

testing['pickup_datetime'] = pd.to_datetime(testing['pickup_datetime'])
testing["year"] = testing['pickup_datetime'].dt.year
testing["month"] = testing['pickup_datetime'].dt.month
testing["day"] = testing['pickup_datetime'].dt.day
testing["hour"] = testing['pickup_datetime'].dt.hour
testing["minute"] = testing['pickup_datetime'].dt.minute
testing["dayofweek"] = testing['pickup_datetime'].dt.dayofweek
testing = testing.drop(['key'], axis=1)
testing = testing.drop(['pickup_datetime'], axis=1)
testing = testing.dropna ()
testing.isna().any()

x = testing.values
x_scaled = min_max_scaler.fit_transform(x)
testing=pd.DataFrame(x_scaled, columns=testing.columns)
pred_test = model.predict(testing)

# %%
pred = pd.DataFrame(pred_test, columns=['fare_amount'])
testing1 = pd.concat([pred, testing], axis = 1)
testing1.head ()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0     0.100987          0.220338         0.167776           0.221502
# 1     0.103208          0.209638         0.128686           0.207781
# 2     0.094220          0.213066         0.156736           0.222898
# 3     0.097566          0.214143         0.171297           0.214414
# 4     0.096762          0.226085         0.190628           0.215894
#
#    dropoff_latitude  passenger_count      year     month       day      hour  \
# 0          0.155060              0.0  1.000000  0.000000  0.866667  0.565217
# 1          0.150950              0.0  1.000000  0.000000  0.866667  0.565217
# 2          0.157102              0.0  0.333333  0.818182  0.233333  0.478261
# 3          0.161976              0.0  0.500000  1.000000  0.000000  0.913043
# 4          0.155584              0.0  0.500000  1.000000  0.000000  0.913043
#
#      minute  dayofweek
# 0  0.135593   0.166667
# 1  0.135593   0.166667
# ...

# %%
testing2 = min_max_scaler.inverse_transform(testing1)

# %%
testing3 = pd.DataFrame(testing2, columns=testing1.columns)

# %%
testing3.head ()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0    17.500442        -49.811869         5.701732         -56.865375
# 1    17.951165        -51.055154       -12.869464         -58.586679
# 2    16.126667        -50.656872         0.456986         -56.690242
# 3    16.805882        -50.531646         7.374651         -57.754615
# 4    16.642756        -49.144055        16.558629         -57.568937
#
#    dropoff_latitude  passenger_count    year  month   day  hour  minute  \
# 0        -55.799016              0.0  2015.0    1.0  27.0  13.0     8.0
# 1        -56.281616              0.0  2015.0    1.0  27.0  13.0     8.0
# 2        -55.559162              0.0  2011.0   10.0   8.0  11.0    53.0
# 3        -54.986897              0.0  2012.0   12.0   1.0  21.0    12.0
# 4        -55.737422              0.0  2012.0   12.0   1.0  21.0    12.0
#
#    dayofweek
# 0        1.0
# 1        1.0
# 2        5.0
# 3        5.0
# 4        5.0

# %%
testing2 = pd.read_csv('/content/gdrive/My Drive/data_stud/machlearn/test.csv')
testing2.head ()
# Out:
#                            key          pickup_datetime  pickup_longitude  \
# 0  2015-01-27 13:08:24.0000002  2015-01-27 13:08:24 UTC        -73.973320
# 1  2015-01-27 13:08:24.0000003  2015-01-27 13:08:24 UTC        -73.986862
# 2  2011-10-08 11:53:44.0000002  2011-10-08 11:53:44 UTC        -73.982524
# 3  2012-12-01 21:12:12.0000002  2012-12-01 21:12:12 UTC        -73.981160
# 4  2012-12-01 21:12:12.0000003  2012-12-01 21:12:12 UTC        -73.966046
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0        40.763805         -73.981430         40.743835                1
# 1        40.719383         -73.998886         40.739201                1
# 2        40.751260         -73.979654         40.746139                1
# 3        40.767807         -73.990448         40.751635                1
# 4        40.789775         -73.988565         40.744427                1

# %%
testing4 = pd.concat([testing2['key'], testing3['fare_amount']], axis = 1)
testing4.head ()
# Out:
#                            key  fare_amount
# 0  2015-01-27 13:08:24.0000002    17.500442
# 1  2015-01-27 13:08:24.0000003    17.951165
# 2  2011-10-08 11:53:44.0000002    16.126667
# 3  2012-12-01 21:12:12.0000002    16.805882
# 4  2012-12-01 21:12:12.0000003    16.642756

# %%
testing4.to_csv('/content/gdrive/My Drive/data_stud/machlearn/kaggle.csv', index=False)
